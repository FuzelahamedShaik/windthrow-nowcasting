# %%
from altair import MultiPoint
# !pip install fmiopendata

# %%
import datetime as dt
from fmiopendata.wfs import download_stored_query

# %%
now = dt.datetime.utcnow()
start_time = now.strftime('%Y-%m-%dT00:00:00Z')
end_time = now.strftime('%Y-%m-%dT18:00:00Z')
model_data = download_stored_query("fmi::forecast::harmonie::surface::grid",
                                   args=["starttime=" + start_time,
                                         "endtime=" + end_time,
                                         "bbox=18,55,35,75"])

# %%
print(model_data.data)
# Out:
# {datetime.datetime(2025, 12, 5, 6, 0): <fmiopendata.grid.Grid object at 0x7a03e3d149a0>, datetime.datetime(2025, 12, 5, 9, 0): <fmiopendata.grid.Grid object at 0x7a03f97f63e0>}

# %%
latest_run = max(model_data.data.keys())
data = model_data.data[latest_run]
data.parse(delete=True)

# %%
valid_times = data.data.keys()
print(list(valid_times))
# Out:
# [datetime.datetime(2025, 12, 5, 9, 0), datetime.datetime(2025, 12, 5, 10, 0), datetime.datetime(2025, 12, 5, 11, 0), datetime.datetime(2025, 12, 5, 12, 0), datetime.datetime(2025, 12, 5, 13, 0), datetime.datetime(2025, 12, 5, 14, 0), datetime.datetime(2025, 12, 5, 15, 0), datetime.datetime(2025, 12, 5, 16, 0), datetime.datetime(2025, 12, 5, 17, 0), datetime.datetime(2025, 12, 5, 18, 0)]

# %%
earliest_step = min(valid_times)
data_levels = data.data[earliest_step].keys()
print(list(data_levels))
# Out:
# [0, 2, 10]

# %%
for level in data_levels:
    datasets = data.data[earliest_step][level]
    for dset in datasets:
        unit = datasets[dset]["units"]
        data_array = datasets[dset]["data"]
        print("Level: %d, dataset name: %s, data unit: %s" % (level, dset, unit))
# Out:
# Level: 0, dataset name: Mean sea level pressure, data unit: Pa
# Level: 0, dataset name: Orography, data unit: m
# Level: 0, dataset name: Wind speed (gust), data unit: m s**-1
# Level: 0, dataset name: Surface short-wave (solar) radiation downwards, data unit: J m**-2
# Level: 0, dataset name: Surface net long-wave (thermal) radiation, data unit: J m**-2
# Level: 0, dataset name: Surface net short-wave (solar) radiation, data unit: J m**-2
# Level: 0, dataset name: Surface direct short-wave (solar) radiation, data unit: J m**-2
# Level: 2, dataset name: 2 metre temperature, data unit: K
# Level: 2, dataset name: 2 metre dewpoint temperature, data unit: K
# Level: 2, dataset name: 2 metre relative humidity, data unit: %
# Level: 10, dataset name: Mean wind direction, data unit: degrees
# Level: 10, dataset name: 10 metre wind speed, data unit: m s**-1
# Level: 10, dataset name: 10 metre U wind component, data unit: m s**-1
# Level: 10, dataset name: 10 metre V wind component, data unit: m s**-1
# Level: 10, dataset name: surface precipitation amount, rain, convective, data unit: kg m**-2
# Level: 10, dataset name: Convective available potential energy, data unit: J kg**-1
# Level: 10, dataset name: Total Cloud Cover, data unit: %
# Level: 10, dataset name: Low cloud cover, data unit: (0 - 1)
# Level: 10, dataset name: Medium cloud cover, data unit: (0 - 1)
# Level: 10, dataset name: High cloud cover, data unit: (0 - 1)
# Level: 10, dataset name: Global radiation flux, data unit: W m**-2
# Level: 10, dataset name: Visibility, data unit: m

# %%
from src.utils.geoutils import grid_to_long_dataframe
df_grid = grid_to_long_dataframe(data)
df_grid.head()
# Out:
# Grid has 10 valid times

# %%
import datetime as dt
from fmiopendata.wfs import download_stored_query

end_time = dt.datetime.utcnow()
start_time = end_time - dt.timedelta(hours=1)

start_time = start_time.isoformat(timespec='seconds') + "Z"

end_time = end_time.isoformat(timespec='seconds') + "Z"

obs = download_stored_query("fmi::observations::weather::multipointcoverage",
                            args=["bbox=18,55,35,75",
                                  "starttime=" + start_time,
                                  "endtime=" + end_time])

# %%
print(sorted(obs.data.keys()))
# Out:
# [datetime.datetime(2025, 12, 29, 7, 52), datetime.datetime(2025, 12, 29, 7, 53), datetime.datetime(2025, 12, 29, 7, 54), datetime.datetime(2025, 12, 29, 7, 55), datetime.datetime(2025, 12, 29, 7, 56), datetime.datetime(2025, 12, 29, 7, 57), datetime.datetime(2025, 12, 29, 7, 58), datetime.datetime(2025, 12, 29, 7, 59), datetime.datetime(2025, 12, 29, 8, 0), datetime.datetime(2025, 12, 29, 8, 1), datetime.datetime(2025, 12, 29, 8, 2), datetime.datetime(2025, 12, 29, 8, 3), datetime.datetime(2025, 12, 29, 8, 4), datetime.datetime(2025, 12, 29, 8, 5), datetime.datetime(2025, 12, 29, 8, 6), datetime.datetime(2025, 12, 29, 8, 7), datetime.datetime(2025, 12, 29, 8, 8), datetime.datetime(2025, 12, 29, 8, 9), datetime.datetime(2025, 12, 29, 8, 10), datetime.datetime(2025, 12, 29, 8, 11), datetime.datetime(2025, 12, 29, 8, 12), datetime.datetime(2025, 12, 29, 8, 13), datetime.datetime(2025, 12, 29, 8, 14), datetime.datetime(2025, 12, 29, 8, 15), datetime.datetime(2025, 12, 29, 8, 16), datetime.datetime(2025, 12, 29, 8, 17), datetime.datetime(2025, 12, 29, 8, 18), datetime.datetime(2025, 12, 29, 8, 19), datetime.datetime(2025, 12, 29, 8, 20), datetime.datetime(2025, 12, 29, 8, 21), datetime.datetime(2025, 12, 29, 8, 22), datetime.datetime(2025, 12, 29, 8, 23), datetime.datetime(2025, 12, 29, 8, 24), datetime.datetime(2025, 12, 29, 8, 25), datetime.datetime(2025, 12, 29, 8, 26), datetime.datetime(2025, 12, 29, 8, 27), datetime.datetime(2025, 12, 29, 8, 28), datetime.datetime(2025, 12, 29, 8, 29), datetime.datetime(2025, 12, 29, 8, 30), datetime.datetime(2025, 12, 29, 8, 31), datetime.datetime(2025, 12, 29, 8, 32), datetime.datetime(2025, 12, 29, 8, 33), datetime.datetime(2025, 12, 29, 8, 34), datetime.datetime(2025, 12, 29, 8, 35), datetime.datetime(2025, 12, 29, 8, 36), datetime.datetime(2025, 12, 29, 8, 37), datetime.datetime(2025, 12, 29, 8, 38), datetime.datetime(2025, 12, 29, 8, 39), datetime.datetime(2025, 12, 29, 8, 40), datetime.datetime(2025, 12, 29, 8, 41), datetime.datetime(2025, 12, 29, 8, 42), datetime.datetime(2025, 12, 29, 8, 43), datetime.datetime(2025, 12, 29, 8, 44), datetime.datetime(2025, 12, 29, 8, 45), datetime.datetime(2025, 12, 29, 8, 46), datetime.datetime(2025, 12, 29, 8, 47), datetime.datetime(2025, 12, 29, 8, 48), datetime.datetime(2025, 12, 29, 8, 49), datetime.datetime(2025, 12, 29, 8, 50)]

# %%
# The next level has the names of the observation stations as keys
latest_tstep = max(obs.data.keys())
print(sorted(obs.data[latest_tstep].keys()))
# Out:
# ['Enontekiö Kilpisjärvi Saana', 'Kotka Rankki', 'Kouvola Anjala', 'Lohja Porla', 'Sotkamo Kuolaniemi', 'Vaasa Klemettilä', 'Varkaus Kosulanniemi', 'Viitasaari Haapaniemi']

# %%
print(sorted(obs.data[latest_tstep]["Kouvola Anjala"].keys()))
# Out:
# ['Air temperature', 'Cloud amount', 'Dew-point temperature', 'Gust speed', 'Horizontal visibility', 'Precipitation amount', 'Precipitation intensity', 'Present weather (auto)', 'Pressure (msl)', 'Relative humidity', 'Snow depth', 'Wind direction', 'Wind speed']

# %%
print(obs.data[latest_tstep]["Kouvola Anjala"]["Air temperature"])
# Out:
# {'value': np.float64(-1.8), 'units': 'degC'}

# %%
print(obs.location_metadata["Kouvola Anjala"])
# Out:
# {'fmisid': 101194, 'latitude': 60.6965, 'longitude': 26.81106}

# %%
# Limit the time
now = dt.datetime.utcnow()
# Depending on the current time and availability of the model data, adjusting
# the hours below might be necessary to get any data
start_time = now.strftime('%Y-%m-%dT00:00:00Z')
end_time = now.strftime('%Y-%m-%dT18:00:00Z')
model_data = download_stored_query("fmi::forecast::harmonie::surface::grid",
                                   args=["starttime=" + start_time,
                                         "endtime=" + end_time,
                                         "bbox=18,55,35,75"])

# %%
print(model_data.data)
# Out:
# {datetime.datetime(2025, 12, 29, 0, 0): <fmiopendata.grid.Grid object at 0x743120f41de0>, datetime.datetime(2025, 12, 29, 3, 0): <fmiopendata.grid.Grid object at 0x7431805da590>, datetime.datetime(2025, 12, 29, 6, 0): <fmiopendata.grid.Grid object at 0x74311f503520>}

# %%
latest_run = max(model_data.data.keys())  # datetime.datetime(2020, 7, 7, 12, 0)
data = model_data.data[latest_run]

# %%
valid_times = data.data.keys()
print(list(valid_times))
# Out:
# []

# %%
import pandas as pd

df = pd.read_parquet(
    "../data/interim/cap_parsed/cap_alerts_latest.parquet",
    engine="pyarrow"
)

# %%
df.head()
# Out:
#                                           identifier  \
# 0  urn:oid:2.49.0.1.246.0.0.2025.31312178.2153393...
# 1  urn:oid:2.49.0.1.246.0.0.2025.31312178.1859886...
# 2  urn:oid:2.49.0.1.246.0.0.2025.31312178.1817834...
# 3  urn:oid:2.49.0.1.246.0.0.2025.31312178.3038955...
# 4  urn:oid:2.49.0.1.246.0.0.2025.31312178.1245277...
#
#                         sent                  sender  status msg_type   scope  \
# 0  2025-12-29T11:49:38+02:00  urn:oid:2.49.0.0.246.0  Actual   Update  Public
# 1  2025-12-29T11:49:38+02:00  urn:oid:2.49.0.0.246.0  Actual   Update  Public
# 2  2025-12-29T11:49:38+02:00  urn:oid:2.49.0.0.246.0  Actual   Update  Public
# 3  2025-12-29T11:49:38+02:00  urn:oid:2.49.0.0.246.0  Actual   Update  Public
# 4  2025-12-29T11:49:38+02:00  urn:oid:2.49.0.0.246.0  Actual   Update  Public
#
#   language_first            event_first severity_first urgency_first  \
# 0          fi-FI  Tuulivaroitus merelle       Moderate     Immediate
# 1          fi-FI  Tuulivaroitus merelle       Moderate     Immediate
# 2          fi-FI            Liikennesää       Moderate        Future
# 3          fi-FI  Tuulivaroitus merelle       Moderate        Future
# 4          fi-FI       Jäätämisvaroitus       Moderate      Expected
#
#   certainty_first effective_first                onset_first  \
# 0          Likely            None  2025-12-29T11:49:38+02:00
# 1          Likely            None  2025-12-29T11:49:38+02:00
# 2        Possible            None  2026-01-02T00:00:00+02:00
# 3        Possible            None  2025-12-30T00:00:00+02:00
# 4        Possible            None  2025-12-29T14:00:00+02:00
#
#                expires_first  \
# 0  2025-12-30T00:00:00+02:00
# 1  2025-12-30T00:00:00+02:00
# 2  2026-01-03T00:00:00+02:00
# 3  2025-12-30T20:00:00+02:00
# 4  2025-12-30T17:00:00+02:00
#
#                                         headline_all  \
# 0  Keltainen tuulivaroitus merelle: Suomenlahden ...
# 1  Keltainen tuulivaroitus merelle: Paikoin kaikk...
# 2  Keltainen liikennesää: Paikoin maan eteläosa, ...
# 3  Keltainen tuulivaroitus merelle: Suomenlahti j...
# 4  Keltainen jäätämisvaroitus: Perämeri, ma 14.00...
#
#                                      description_all instruction_all  \
# 0  Kovan tuulen varoitus: Pohjoisen ja luoteen vä...            None
# 1  Kovan tuulen varoitus: Pohjoisen ja luoteen vä...            None
# 2  Liikennesää: Huonon ajokelin todennäköisyys on...            None
# 3  Kovan tuulen varoitus: Pohjoistuulta keskiyöst...            None
# 4  Jäätämisvaroitus: Jään kertyminen alusten rake...            None
#
#          area_desc_first                                         source_url  \
# 0  Suomenlahden länsiosa  https://alerts.fmi.fi/cap/2025/12-29/09-49-38Z...
# 1            Ahvenanmeri  https://alerts.fmi.fi/cap/2025/12-29/09-49-38Z...
# 2        Varsinais-Suomi  https://alerts.fmi.fi/cap/2025/12-29/09-49-38Z...
# 3  Suomenlahden länsiosa  https://alerts.fmi.fi/cap/2025/12-29/09-49-38Z...
# 4   Perämeren pohjoisosa  https://alerts.fmi.fi/cap/2025/12-29/09-49-38Z...
#
#                                             raw_path
# 0  data/raw/fmi_cap_xml/urn_oid_2.49.0.1.246.0.0....
# 1  data/raw/fmi_cap_xml/urn_oid_2.49.0.1.246.0.0....
# 2  data/raw/fmi_cap_xml/urn_oid_2.49.0.1.246.0.0....
# 3  data/raw/fmi_cap_xml/urn_oid_2.49.0.1.246.0.0....
# 4  data/raw/fmi_cap_xml/urn_oid_2.49.0.1.246.0.0....

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   identifier       20 non-null     object
#  1   sent             20 non-null     object
#  2   sender           20 non-null     object
#  3   status           20 non-null     object
#  4   msg_type         20 non-null     object
#  5   scope            20 non-null     object
#  6   language_first   20 non-null     object
#  7   event_first      20 non-null     object
#  8   severity_first   20 non-null     object
#  9   urgency_first    20 non-null     object
#  10  certainty_first  20 non-null     object
#  11  effective_first  0 non-null      object
#  12  onset_first      20 non-null     object
#  13  expires_first    20 non-null     object
#  14  headline_all     20 non-null     object
#  15  description_all  20 non-null     object
#  16  instruction_all  0 non-null      object
#  17  area_desc_first  20 non-null     object
#  18  source_url       20 non-null     object
#  19  raw_path         20 non-null     object
# dtypes: object(20)
# memory usage: 3.2+ KB

# %%
import pandas as pd

df = pd.read_parquet(
    "../data/interim/forest_stands/stands_eaf55fea1f_20260109T091220Z.parquet",
    engine="pyarrow"
)

# %%
df.head()
# Out:
#                id  STANDNUMBER STANDNUMBEREXTENSION  MAINGROUP  SUBGROUP  \
# 0  stand.38121345          190                 None          1         1
# 1  stand.38121346          212                 None          1         1
# 2  stand.38121347          202                 None          2         3
# 3  stand.38122343            9                 None          1         1
# 4  stand.38123206            3                 None          1         1
#
#    FERTILITYCLASS  SOILTYPE  DRAINAGESTATE  DITCHINGYEAR DEVELOPMENTCLASS  \
# 0               3        10              3           NaN               03
# 1               4        10              1           NaN               03
# 2               5        60              7        1981.0             None
# 3               4        10              1           NaN               03
# 4               4        10              1           NaN               03
#
#    ...             TREESTANDDATE  CUTTINGTYPE  CUTTINGPROPOSALYEAR  \
# 0  ... 2025-12-31 22:00:00+00:00          3.0               2033.0
# 1  ... 2025-12-31 22:00:00+00:00          3.0               2027.0
# 2  ... 2025-12-31 22:00:00+00:00          NaN                  NaN
# 3  ... 2025-12-31 22:00:00+00:00          2.0               2026.0
# 4  ... 2025-12-31 22:00:00+00:00          3.0               2026.0
#
#    SILVICULTURETYPE  SILVICULTUREPROPOSALYEAR              CREATIONTIME  \
# 0               NaN                       NaN 2021-07-02 02:02:54+00:00
# 1               NaN                       NaN 2021-07-02 02:02:54+00:00
# 2               NaN                       NaN 2021-07-02 02:02:54+00:00
# 3               NaN                       NaN 2021-07-02 02:05:12+00:00
# 4               NaN                       NaN 2021-07-02 02:07:14+00:00
#
#                         UPDATETIME           source  \
# 0 2025-09-08 13:41:03.723000+00:00  metsakeskus_wfs
# 1 2025-09-08 13:41:03.723000+00:00  metsakeskus_wfs
# 2 2025-09-08 13:41:03.723000+00:00  metsakeskus_wfs
# 3 2025-09-10 22:48:02.494000+00:00  metsakeskus_wfs
# 4 2025-09-13 09:22:10.900000+00:00  metsakeskus_wfs
#
#                     ingested_at_utc  \
# 0  2026-01-09T09:12:18.384947+00:00
# 1  2026-01-09T09:12:18.384947+00:00
# 2  2026-01-09T09:12:18.384947+00:00
# 3  2026-01-09T09:12:18.384947+00:00
# 4  2026-01-09T09:12:18.384947+00:00
#
#                                         geometry_wkt
# 0  POLYGON ((25.388614 65.384706, 25.388669 65.38...
# 1  POLYGON ((25.389335 65.382687, 25.389027 65.38...
# 2  POLYGON ((25.387544 65.384621, 25.38737 65.384...
# 3  POLYGON ((25.361053 65.362363, 25.361046 65.36...
# 4  POLYGON ((25.40687 65.413773, 25.406865 65.413...
#
# [5 rows x 44 columns]

# %%
df.columns
# Out:
# Index(['id', 'STANDNUMBER', 'STANDNUMBEREXTENSION', 'MAINGROUP', 'SUBGROUP',
#        'FERTILITYCLASS', 'SOILTYPE', 'DRAINAGESTATE', 'DITCHINGYEAR',
#        'DEVELOPMENTCLASS', 'STANDQUALITY', 'ACCESSIBILITY', 'AREA',
#        'AREADECREASE', 'STANDCLASS', 'TREESTANDDATASOURCE', 'MEASUREMENTDATE',
#        'CUTTINGRESTRICTION', 'SILVICULTURERESTRICTION', 'SPECIALFEATURECODE',
#        'SPECIALFEATUREADDITIONALCODE', 'MAINTREESPECIES', 'PROPORTIONPINE',
#        'PROPORTIONSPRUCE', 'PROPORTIONOTHER', 'MEANAGE', 'BASALAREA',
#        'STEMCOUNT', 'MEANDIAMETER', 'MEANHEIGHT', 'VOLUME', 'SAWLOGVOLUME',
#        'PULPWOODVOLUME', 'VOLUMEGROWTH', 'TREESTANDDATE', 'CUTTINGTYPE',
#        'CUTTINGPROPOSALYEAR', 'SILVICULTURETYPE', 'SILVICULTUREPROPOSALYEAR',
#        'CREATIONTIME', 'UPDATETIME', 'source', 'ingested_at_utc',
#        'geometry_wkt'],
#       dtype='object')

# %%
df.dtypes
# Out:
# id                                           object
# STANDNUMBER                                   int32
# STANDNUMBEREXTENSION                         object
# MAINGROUP                                     int32
# SUBGROUP                                      int32
# FERTILITYCLASS                                int32
# SOILTYPE                                      int32
# DRAINAGESTATE                                 int32
# DITCHINGYEAR                                float64
# DEVELOPMENTCLASS                             object
# STANDQUALITY                                 object
# ACCESSIBILITY                               float64
# AREA                                        float64
# AREADECREASE                                  int32
# STANDCLASS                                    int32
# TREESTANDDATASOURCE                          object
# MEASUREMENTDATE                 datetime64[ms, UTC]
# CUTTINGRESTRICTION                          float64
# SILVICULTURERESTRICTION                     float64
# SPECIALFEATURECODE                          float64
# SPECIALFEATUREADDITIONALCODE                float64
# MAINTREESPECIES                             float64
# PROPORTIONPINE                              float64
# PROPORTIONSPRUCE                            float64
# PROPORTIONOTHER                             float64
# MEANAGE                                       int32
# BASALAREA                                   float64
# STEMCOUNT                                     int32
# MEANDIAMETER                                float64
# MEANHEIGHT                                  float64
# VOLUME                                      float64
# SAWLOGVOLUME                                float64
# PULPWOODVOLUME                              float64
# VOLUMEGROWTH                                float64
# TREESTANDDATE                   datetime64[ms, UTC]
# CUTTINGTYPE                                 float64
# CUTTINGPROPOSALYEAR                         float64
# SILVICULTURETYPE                            float64
# SILVICULTUREPROPOSALYEAR                    float64
# CREATIONTIME                    datetime64[ms, UTC]
# UPDATETIME                      datetime64[ms, UTC]
# source                                       object
# ingested_at_utc                              object
# geometry_wkt                                 object
# dtype: object

# %%
df = pd.read_parquet(
    "../data/interim/fmi/observations/2025/12/29/obs_20251229T091205Z.parquet",
    engine="pyarrow"
)

# %%
df.head()
# Out:
#                obs_time_utc              station_name  fmisid       lat  \
# 0 2025-12-29 08:20:00+00:00  Porvoo Kilpilahti satama  100683  60.30373
# 1 2025-12-29 08:20:00+00:00  Porvoo Kilpilahti satama  100683  60.30373
# 2 2025-12-29 08:20:00+00:00  Porvoo Kilpilahti satama  100683  60.30373
# 3 2025-12-29 08:20:00+00:00  Porvoo Kilpilahti satama  100683  60.30373
# 4 2025-12-29 08:20:00+00:00  Porvoo Kilpilahti satama  100683  60.30373
#
#         lon          parameter  value  unit
# 0  25.54916    Air temperature   -1.3  degC
# 1  25.54916         Wind speed    7.2   m/s
# 2  25.54916         Gust speed   10.2   m/s
# 3  25.54916     Wind direction  292.0   deg
# 4  25.54916  Relative humidity   76.0     %

# %%
df.columns
# Out:
# Index(['obs_time_utc', 'station_name', 'fmisid', 'lat', 'lon', 'parameter',
#        'value', 'unit'],
#       dtype='object')

# %%
df = pd.read_parquet(
    "../data/interim/cap_parsed/cap_alerts_latest.parquet",
    engine="pyarrow"
)

# %%
df.head()
# Out:
#                                           identifier  \
# 0  urn:oid:2.49.0.1.246.0.0.2026.563217.234666668...
# 1  urn:oid:2.49.0.1.246.0.0.2026.563217.261124023...
# 2  urn:oid:2.49.0.1.246.0.0.2026.563217.560629337...
# 3  urn:oid:2.49.0.1.246.0.0.2026.563217.243390458...
#
#                         sent                  sender  status msg_type   scope  \
# 0  2026-01-07T14:26:57+02:00  urn:oid:2.49.0.0.246.0  Actual   Update  Public
# 1  2026-01-07T14:26:57+02:00  urn:oid:2.49.0.0.246.0  Actual   Update  Public
# 2  2026-01-07T14:26:57+02:00  urn:oid:2.49.0.0.246.0  Actual   Update  Public
# 3  2026-01-07T14:26:57+02:00  urn:oid:2.49.0.0.246.0  Actual   Update  Public
#
#   language_first            event_first severity_first urgency_first  ...  \
# 0          fi-FI       Jäätämisvaroitus       Moderate     Immediate  ...
# 1          fi-FI         Pakkasvaroitus       Moderate     Immediate  ...
# 2          fi-FI  Tuulivaroitus merelle       Moderate      Expected  ...
# 3          fi-FI            Liikennesää       Moderate     Immediate  ...
#
#                  onset_first              expires_first  \
# 0  2026-01-07T14:26:57+02:00  2026-01-08T00:00:00+02:00
# 1  2026-01-07T14:26:57+02:00  2026-01-07T23:00:00+02:00
# 2  2026-01-07T17:00:00+02:00  2026-01-08T00:00:00+02:00
# 3  2026-01-07T14:26:57+02:00  2026-01-07T20:00:00+02:00
#
#                                         headline_all  \
# 0  Keltainen jäätämisvaroitus: Merenkurkku ja Per...
# 1  Keltainen pakkasvaroitus: Paikoin Lappi, ke 14...
# 2  Keltainen tuulivaroitus merelle: Selkämeri, ke...
# 3  Keltainen liikennesää: Paikoin maan itäosa, ke...
#
#                                      description_all instruction_all  \
# 0  Jäätämisvaroitus: Jään kertyminen alusten rake...            None
# 1  Pakkasvaroitus: Lähivuorokauden aikana esiinty...            None
# 2  Kovan tuulen varoitus: Kaakkoistuulta aluksi 1...            None
# 3  Liikennesää: Ajokeli on huono aluksi lumisatee...            None
#
#        area_desc_first                                         source_url  \
# 0   Perämeren eteläosa  https://alerts.fmi.fi/cap/2026/01-07/12-26-57Z...
# 1             Keminmaa  https://alerts.fmi.fi/cap/2026/01-07/12-26-57Z...
# 2  Selkämeren eteläosa  https://alerts.fmi.fi/cap/2026/01-07/12-26-57Z...
# 3          Kymenlaakso  https://alerts.fmi.fi/cap/2026/01-07/12-26-57Z...
#
#   bbox_match                                           raw_path  \
# 0       None  data/raw/cap_warnings/urn_oid_2.49.0.1.246.0.0...
# 1       None  data/raw/cap_warnings/urn_oid_2.49.0.1.246.0.0...
# 2       None  data/raw/cap_warnings/urn_oid_2.49.0.1.246.0.0...
# 3       None  data/raw/cap_warnings/urn_oid_2.49.0.1.246.0.0...
#
#                                        polygons_json
# 0  ["64.500701,21.473825 64.500701,22.270106 64.5...
# 1  ["66.030445,24.510206 66.017984,24.581556 66.0...
# 2  ["61.998401,17.448946 61.996972,18.22522 61.99...
# 3  ["60.200339,26.875322 60.200191,26.764653 60.1...
#
# [4 rows x 22 columns]

# %%
df.columns
# Out:
# Index(['identifier', 'sent', 'sender', 'status', 'msg_type', 'scope',
#        'language_first', 'event_first', 'severity_first', 'urgency_first',
#        'certainty_first', 'effective_first', 'onset_first', 'expires_first',
#        'headline_all', 'description_all', 'instruction_all', 'area_desc_first',
#        'source_url', 'bbox_match', 'raw_path', 'polygons_json'],
#       dtype='object')
